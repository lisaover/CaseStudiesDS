# %% [markdown]
# ## COVID Drivers: Data Preparation

# %% [markdown]
# ### Table of Contents
# * [Read the Data](#read)</BR>
# * [Create New Date Variables](#dates)</BR>
# * [Select Columns and Merge CRASH and FLAGS](#cols)</BR>
# * [Select Rows with Vehicles in Transit or Hit and Run](#rows)</BR>
# * [Check Balance of Data Between Pre- and Post-COVID](#balance)</BR>
# * [Decode Categorical Variables](#decode)</BR>
# * [Write Final Dataset to File](#write)

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
# Import project specific utilities
from utils.functions import *

# %% [markdown]
# ### <a id='read'>Read the Data</a>

# %%
crash = pd.DataFrame()
flags = pd.DataFrame()
person = pd.DataFrame()
vehicle = pd.DataFrame()

for folder in os.listdir(path_raw):
    #print(folder)
    year = folder[-4:]
    #print(year)
    if 'statewide' in folder.lower():
    #if year != '2020' and 'statewide' in folder.lower():
        tmp = read_data(folder, year, 'CRASH')
        crash = (tmp.copy() if crash.empty else crash.copy() if tmp.empty
            else pd.concat([crash, tmp]) # if both DataFrames non empty
        )

        tmp = read_data(folder, year, 'FLAGS')
        flags = (tmp.copy() if flags.empty else flags.copy() if tmp.empty
            else pd.concat([flags, tmp]) # if both DataFrames non empty
        )

        tmp = read_data(folder, year, 'PERSON')
        person = (tmp.copy() if person.empty else person.copy() if tmp.empty
            else pd.concat([person, tmp]) # if both DataFrames non empty
        )

        tmp = read_data(folder, year, 'VEHICLE')
        vehicle = (tmp.copy() if vehicle.empty else vehicle.copy() if tmp.empty
            else pd.concat([vehicle, tmp]) # if both DataFrames non empty
        )

# %%
#set(flags.columns.tolist())

# %%
for c in flags.columns.tolist():
    if flags[c].isna().sum() > 0:
        print(c + ' has ' + str(flags[c].isna().sum()) + ' missing values')
# Out:
# HORSE_BUGGY has 12350 missing values
# LIMIT_70MPH has 1453 missing values

# %% [markdown]
# Proportion of values that are one for ech variable in full dataset

# %%
gte15_all = {}
gte10_all = {}
lt10_all = {}

for c in flags.columns.tolist():
    pct = round(flags.loc[flags[c]==1].shape[0]/flags.shape[0]*100, 2)
    if pct >= 15:
        gte15_all[c] = pct
    elif pct >= 10:
        gte10_all[c] = pct
    else:
        lt10_all[c] = pct


print('Greater than or equal to 15%')
print()
for k, v in gte15_all.items():
    print(k + ': ' + str(v) + '%')

print()
print('Greater than or equal to 10%')
print()
for k, v in gte10_all.items():
    print(k + ': ' + str(v) + '%')

print()
print('Less than 10%')
print()
for k, v in lt10_all.items():
    print(k + ': ' + str(v) + '%')
# Out:
# Greater than or equal to 15%
#
# AGGRESSIVE_DRIVING: 55.96%
# ANGLE_CRASH: 26.34%
# CURVED_ROAD: 18.97%
# DRIVER_50_64YR: 27.2%
# HIT_FIXED_OBJECT: 31.08%
# ILLUMINATION_DARK: 33.38%
# INJURY: 47.95%
# INJURY_OR_FATAL: 48.52%
# INTERSECTION: 38.06%
# LANE_DEPARTURE: 33.03%
# LEFT_TURN: 15.49%
# LOCAL_ROAD: 46.22%
# LOCAL_ROAD_ONLY: 26.57%
# MATURE_DRIVER: 15.53%
# MULTIPLE_VEHICLE: 59.39%
# NON_INTERSECTION: 61.94%
# POSSIBLE_INJURY: 20.34%
# PROPERTY_DAMAGE_ONLY: 48.48%
# PSP_REPORTED: 34.62%
# REAR_END: 20.99%
# RURAL: 33.49%
# SIGNALIZED_INT: 15.06%
# SINGLE_VEHICLE: 40.61%
# SPEEDING_RELATED: 25.19%
# STATE_ROAD: 71.36%
# SV_RUN_OFF_RD: 37.25%
# UNSIGNALIZED_INT: 23.0%
# URBAN: 66.51%
# VEHICLE_TOWED: 89.85%
# WET_ROAD: 17.76%
# YOUNG_DRIVER: 19.87%
#
# Greater than or equal to 10%
#
# CORE_NETWORK: 14.32%
# DISTRACTED: 10.79%
# IMPAIRED_DRIVER: 10.19%
# STOP_CONTROLLED_INT: 11.99%
# SUSPECTED_MINOR_INJURY: 14.87%
# UNBELTED: 11.8%
#
# Less than 10%
#
# CRN: 0.0%
# ALCOHOL_RELATED: 8.72%
# ATV: 0.18%
# ATV_ROUTE: 0.0%
# BACKUP_CONGESTION: 0.14%
# BACKUP_NONRECURRING: 0.03%
# BACKUP_PRIOR: 0.05%
# BICYCLE: 1.01%
# CELL_PHONE: 1.04%
# CHILD_PASSENGER: 6.32%
# COMM_VEHICLE: 6.12%
# CROSS_MEDIAN: 2.03%
# CURVE_DVR_ERROR: 3.92%
# DEER_RELATED: 4.14%
# DRINKING_DRIVER: 8.52%
# DRIVER_16YR: 1.68%
# DRIVER_17YR: 4.22%
# DRIVER_18YR: 4.97%
# DRIVER_19YR: 4.91%
# DRIVER_20YR: 4.73%
# DRIVER_65_74YR: 9.59%
# DRIVER_75PLUS: 6.48%
# DRUGGED_DRIVER: 2.72%
# DRUG_RELATED: 2.78%
# FATAL: 0.95%
# FATAL_OR_SUSP_SERIOUS_INJ: 3.73%
# FATIGUE_ASLEEP: 1.99%
# FEDERAL_AID_ROUTE: 0.08%
# FIRE_IN_VEHICLE: 0.51%
# HAZARDOUS_TRUCK: 0.13%
# HIT_BARRIER: 3.73%
# HIT_BRIDGE: 0.53%
# HIT_DEER: 3.0%
# HIT_EMBANKMENT: 5.71%
# HIT_GDRAIL: 4.91%
# HIT_GDRAIL_END: 0.81%
# HIT_PARKED_VEHICLE: 6.29%
# HIT_POLE: 7.28%
# HIT_ROADWAY_EQUIPMENT: 0.03%
# HIT_RUN: 7.26%
# HIT_TEMP_CONSTRUCTION_BARRIER: 0.05%
# HIT_TRAFFIC_ISLAND: 0.19%
# HIT_TREE_SHRUB: 7.24%
# HIT_UTILITY_POLE: 7.03%
# HORSE_BUGGY: 0.05%
# HO_OPPDIR_SDSWP: 5.71%
# HVY_TRUCK_RELATED: 5.54%
# ICY_ROAD: 3.41%
# ILLEGAL_DRUG_RELATED: 2.24%
# IMPAIRED_NONMOTORIST: 0.2%
# INTERSECTION_RELATED: 0.23%
# INTERSTATE: 7.87%
# LIMIT_65MPH: 4.13%
# LIMIT_70MPH: 1.08%
# MARIJUANA_DRUGGED_DRIVER: 0.23%
# MARIJUANA_RELATED: 0.24%
# MC_DRINKING_DRIVER: 0.27%
# MOTORCYCLE: 2.91%
# NHTSA_AGG_DRIVING: 5.31%
# NO_CLEARANCE: 6.82%
# OPIOID_RELATED: 0.1%
# OTHER_FREEWAY_EXPRESSWAY: 4.58%
# OVERTURNED: 6.39%
# PEDESTRIAN: 3.29%
# PHANTOM_VEHICLE: 0.59%
# RAMP: 3.44%
# RAMP_SEGMENT: 0.62%
# RAMP_TERMINAL: 1.53%
# ROUNDABOUT: 0.03%
# RUNNING_RED_LT: 3.67%
# RUNNING_STOP_SIGN: 2.54%
# SCHOOL_BUS: 0.28%
# SCHOOL_BUS_RELATED: 0.59%
# SCHOOL_BUS_UNIT: 0.28%
# SCHOOL_ZONE: 0.34%
# SHLDR_RELATED: 0.14%
# SNOWMOBILE: 0.01%
# SNOW_SLUSH_ROAD: 5.28%
# SPEEDING: 3.51%
# SPEED_CHANGE_LANE: 1.35%
# SUDDEN_DEER: 4.08%
# SUSPECTED_SERIOUS_INJURY: 2.92%
# TAILGATING: 4.67%
# TRAIN: 0.02%
# TRAIN_TROLLEY: 0.05%
# TROLLEY: 0.02%
# TURNPIKE: 2.03%
# UNDERAGE_DRNK_DRV: 0.64%
# UNLICENSED: 0.53%
# VEHICLE_FAILURE: 4.6%
# VULNERABLE_ROAD_USER: 4.27%
# VULNERABLE_ROAD_USER_FATAL: 0.14%
# WORK_ZONE: 1.36%

# %%
flags['HORSE_BUGGY'].sum()
# Out:
# np.float64(1301.0)

# %%
flags.loc[flags['LIMIT_70MPH'].isna()]['LIMIT_65MPH'].value_counts()
# Out:
# LIMIT_65MPH
# 0    1453
# Name: count, dtype: int64

# %%
flags.loc[(flags['LIMIT_70MPH']==1) & flags['LIMIT_65MPH']==1].shape[0]
# Out:
# 6584

# %%
flags.loc[flags['LIMIT_70MPH']==1].shape[0]
# Out:
# 26626

# %% [markdown]
# ### <a id='dates'>Create New Date Variables</a>

# %%
crash2 = crash.copy()

# %%
crash2['POST_COVID'] = [1 if (i > 2020) or (i == 2020 and j >= 3) else 0 for (i, j) in zip(crash2['CRASH_YEAR'], crash2['CRASH_MONTH'])]

# %%
#crash2['COVID'] = ['Post COVID' if (i > 2020) or (i == 2020 and j >= 3) else 'Pre COVID' for (i, j) in zip(crash2['CRASH_YEAR'], crash2['CRASH_MONTH'])]

# %%
crash2['CRASH_MN_NAME'] = pd.to_datetime(crash2['CRASH_MONTH'], format='%m').dt.month_name().str[:3]

# %%
crash2['CRASH_YEAR'] = crash2['CRASH_YEAR'].astype('int64').astype('str')

# %%
crash2['CRASH_DATE'] = crash2.CRASH_YEAR.str.cat( crash2.CRASH_MN_NAME, sep = '-' )

# %%
crash2['CRASH_DATE'].head()
# Out:
# 0    2005-Jan
# 1    2005-Jan
# 2    2005-Jan
# 3    2005-Jan
# 4    2005-Jan
# Name: CRASH_DATE, dtype: str

# %%
crash2['CRASH_DATE'] = pd.to_datetime( crash2['CRASH_DATE'] )
# Out:
# /var/folders/ns/b_tjb7711nd7hm27qtmj_83w0000gn/T/ipykernel_15943/2587876853.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crash2['CRASH_DATE'] = pd.to_datetime( crash2['CRASH_DATE'] )

# %%
crash2['CRASH_DATE'].head()
# Out:
# 0   2005-01-01
# 1   2005-01-01
# 2   2005-01-01
# 3   2005-01-01
# 4   2005-01-01
# Name: CRASH_DATE, dtype: datetime64[us]

# %% [markdown]
# ### <a id='cols'>Select Columns and Merge CRASH and FLAGS</a>

# %%
crash_cols = ['CRN',
 'CRASH_DATE',
 'COUNTY',
 'URBAN_RURAL']

predict_cols = ['POST_COVID',
 'ALCOHOL_RELATED',
 'CELL_PHONE',
 'DISTRACTED',
 'DRINKING_DRIVER',
 'DRIVER_16YR',
 'DRIVER_17YR',
 'DRIVER_18YR',
 'DRIVER_19YR',
 'DRIVER_20YR',
 'DRIVER_50_64YR',
 'DRIVER_65_74YR',
 'DRIVER_75PLUS',
 'DRUGGED_DRIVER',
 'DRUG_RELATED',
 'FATIGUE_ASLEEP',
 'HIT_RUN',
 'ILLEGAL_DRUG_RELATED',
 'IMPAIRED_DRIVER',
 'IMPAIRED_NONMOTORIST',
 'MARIJUANA_DRUGGED_DRIVER',
 'MARIJUANA_RELATED',
 'MATURE_DRIVER',
 'MC_DRINKING_DRIVER',
 'OPIOID_RELATED',
 'UNDERAGE_DRNK_DRV',
 'UNLICENSED',
 'YOUNG_DRIVER']

veh_cols = ['CRN',
            'UNIT_NUM',
            'UNIT_TYPE']

agg_cols = ['AGGRESSIVE_DRIVING',
 'NHTSA_AGG_DRIVING',
 'NO_CLEARANCE',
 'RUNNING_RED_LT',
 'RUNNING_STOP_SIGN',
 'SPEEDING',
 'SPEEDING_RELATED',
 'TAILGATING']

# %%
df_init = pd.merge(crash2, flags, on='CRN', how='left').copy()

# %% [markdown]
# ### <a id='rows'>Select Rows with Vehicles in Transit or Hit and Run</a>

# %%
vehicle2 = vehicle.copy()

# %%
enum_dict['UNIT_TYPE']
# Out:
# {1: 'Motor vehicle in transport',
#  2: 'Legally parked',
#  3: 'Illegally parked',
#  5: 'Hit and run vehicle',
#  6: 'Disabled from a previous crash',
#  21: 'Train',
#  30: 'Non-Motorist',
#  33: 'Personal Delivery Device',
#  51: 'Phantom vehicle'}

# %%
moving = vehicle2.loc[vehicle2['UNIT_TYPE'].isin([1, 5])].copy()

# %%
select_crn = moving['CRN'].unique().tolist()

# %%
df = df_init.loc[df_init['CRN'].isin(select_crn), crash_cols + predict_cols + agg_cols].copy()

# %%
df_init.shape[0]
# Out:
# 2461193

# %%
df.shape[0]
# Out:
# 2460484

# %% [markdown]
# ### <a id='balance'>Check Balance of Data Predictors</a>

# %%
agg_cols
# Out:
# ['AGGRESSIVE_DRIVING',
#  'NHTSA_AGG_DRIVING',
#  'NO_CLEARANCE',
#  'RUNNING_RED_LT',
#  'RUNNING_STOP_SIGN',
#  'SPEEDING',
#  'SPEEDING_RELATED',
#  'TAILGATING']

# %%
gte15 = {}
gte10 = {}
lt10 = {}

for c in predict_cols:
    pct = round(df.loc[df[c]==1].shape[0]/df.shape[0]*100, 2)
    if pct >= 15:
        gte15[c] = pct
    elif pct >= 10:
        gte10[c] = pct
    else:
        lt10[c] = pct


print('Greater than or equal to 15%')
print()
for k, v in gte15.items():
    print(k + ': ' + str(v) + '%')

print()
print('Greater than or equal to 10%')
print()
for k, v in gte10.items():
    print(k + ': ' + str(v) + '%')

print()
print('Less than 10%')
print()
for k, v in lt10.items():
    print(k + ': ' + str(v) + '%')
# Out:
# Greater than or equal to 15%
#
# POST_COVID: 21.99%
# DRIVER_50_64YR: 27.21%
# MATURE_DRIVER: 15.53%
# YOUNG_DRIVER: 19.88%
#
# Greater than or equal to 10%
#
# DISTRACTED: 10.79%
# IMPAIRED_DRIVER: 10.19%
#
# Less than 10%
#
# ALCOHOL_RELATED: 8.72%
# CELL_PHONE: 1.04%
# DRINKING_DRIVER: 8.52%
# DRIVER_16YR: 1.68%
# DRIVER_17YR: 4.22%
# DRIVER_18YR: 4.97%
# DRIVER_19YR: 4.92%
# DRIVER_20YR: 4.73%
# DRIVER_65_74YR: 9.59%
# DRIVER_75PLUS: 6.48%
# DRUGGED_DRIVER: 2.72%
# DRUG_RELATED: 2.78%
# FATIGUE_ASLEEP: 1.99%
# HIT_RUN: 7.26%
# ILLEGAL_DRUG_RELATED: 2.24%
# IMPAIRED_NONMOTORIST: 0.2%
# MARIJUANA_DRUGGED_DRIVER: 0.23%
# MARIJUANA_RELATED: 0.24%
# MC_DRINKING_DRIVER: 0.27%
# OPIOID_RELATED: 0.1%
# UNDERAGE_DRNK_DRV: 0.64%
# UNLICENSED: 0.53%

# %%
gte10_all
# Out:
# {'CORE_NETWORK': 14.32,
#  'DISTRACTED': 10.79,
#  'IMPAIRED_DRIVER': 10.19,
#  'STOP_CONTROLLED_INT': 11.99,
#  'SUSPECTED_MINOR_INJURY': 14.87,
#  'UNBELTED': 11.8}

# %%
gte10
# Out:
# {'DISTRACTED': 10.79, 'IMPAIRED_DRIVER': 10.19}

# %%
df['CRASH_DATE'].head()
# Out:
# 0   2005-01-01
# 1   2005-01-01
# 2   2005-01-01
# 3   2005-01-01
# 4   2005-01-01
# Name: CRASH_DATE, dtype: datetime64[us]

# %%
start_dt = datetime.strptime('2015-01-01', '%Y-%m-%d')

# %%
new = df.loc[df['CRASH_DATE'] >= start_dt].copy()

# %%
new['POST_COVID'].sum()/new.shape[0]
# Out:
# np.float64(0.4509848052896398)

# %% [markdown]
# ### <a id='decode'>Decode Categorical Variables</a>

# %%
df2 = df.copy()

# %% [markdown]
# COUNTY

# %%
df2['COUNTYx'] = [enum_dict['COUNTY'][i] for i in df2['COUNTY']]

# %% [markdown]
# URBAN_RURAL

# %%
df2['URBAN_RURALx'] = [enum_dict['COUNTY'][i] for i in df2['URBAN_RURAL']]

# %% [markdown]
# ### <a id='write'>Write Final Dataset to File</a>

# %%
path_out = 'data/ready/ready_data.csv'

# %%
df2.to_csv(path_out, index=False)

# %%
df2.columns.tolist()
# Out:
# ['CRN',
#  'CRASH_DATE',
#  'COUNTY',
#  'URBAN_RURAL',
#  'POST_COVID',
#  'ALCOHOL_RELATED',
#  'CELL_PHONE',
#  'DISTRACTED',
#  'DRINKING_DRIVER',
#  'DRIVER_16YR',
#  'DRIVER_17YR',
#  'DRIVER_18YR',
#  'DRIVER_19YR',
#  'DRIVER_20YR',
#  'DRIVER_50_64YR',
#  'DRIVER_65_74YR',
#  'DRIVER_75PLUS',
#  'DRUGGED_DRIVER',
#  'DRUG_RELATED',
#  'FATIGUE_ASLEEP',
#  'HIT_RUN',
#  'ILLEGAL_DRUG_RELATED',
#  'IMPAIRED_DRIVER',
#  'IMPAIRED_NONMOTORIST',
#  'MARIJUANA_DRUGGED_DRIVER',
#  'MARIJUANA_RELATED',
#  'MATURE_DRIVER',
#  'MC_DRINKING_DRIVER',
#  'OPIOID_RELATED',
#  'UNDERAGE_DRNK_DRV',
#  'UNLICENSED',
#  'YOUNG_DRIVER',
#  'AGGRESSIVE_DRIVING',
#  'NHTSA_AGG_DRIVING',
#  'NO_CLEARANCE',
#  'RUNNING_RED_LT',
#  'RUNNING_STOP_SIGN',
#  'SPEEDING',
#  'SPEEDING_RELATED',
#  'TAILGATING',
#  'COUNTYx',
#  'URBAN_RURALx']
